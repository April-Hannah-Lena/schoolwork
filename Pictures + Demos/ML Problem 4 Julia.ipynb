# %% [markdown]
# ### Problem 4 - via Julia

# %%
using LinearAlgebra, Plots

# %%
# 1)
n = 1000
x = rand(n)                                 # uniform over [0,1]
ϵ = 0.5 .* randn(n)                         # standardnormal * 0.25
y = x + ϵ
p = sortperm(x)                             # sort series data
x, y = x[p], y[p]
fig = scatter(x, y)

# %%
# 2)
f(a) = sum(@. (x * a - y)^2)
Df(a) = sum(@. 2 * x * (x * a - y))
DDf = sum(@. 2 * x^2)
a, h = 0.5, 0
f_new, f_old = f(a), Inf
while f_old - f_new > eps()                 # simple newton-method
    h = -Df(a)/DDf                      
    @show a = a + h
    f_old = f_new
    @show f_new = f(a)
end
fig = plot!(0:0.5:1, x -> a*x, linewidth=4)
# Out:
# a = a + h = 0.9596307621479343
# f_new = f(a) = 266.1056622293345
# a = a + h = 0.9596307621479343
# f_new = f(a) = 266.1056622293345

# %%
# 4)
d = 4
ϵ = 0.1 .* randn(n)
y = @. 30 * (x - .25)^2 * (x - .75)^2 + ϵ
fig2 = scatter(x, y)
X = hcat([x.^m for m in 0:d]...)           # flatten arrays
a = (X'X) \ (X'y)
fig2 = plot!(x, z -> sum(a[i+1] * z^(i) for i in 0:d), linewidth=4)
